# %%
import pandas as pd

# %%
dataframe = pd.read_csv("/home/linux/PredictBackup/source/media/db.csv")

# %%
dataframe.describe()
# Out:
#              Tamaño           Mes           Dia           Año     Raiz  \
# count  1.011300e+04  10113.000000  10113.000000  10113.000000  10113.0
# mean   7.196959e+08      5.146643     14.831306   2017.907248      0.0
# std    2.040437e+09      2.581227      8.503095      0.290099      0.0
# min    4.360000e+02      1.000000      1.000000   2017.000000      0.0
# 25%    4.199499e+06      4.000000      7.000000   2018.000000      0.0
# 50%    3.385881e+08      5.000000     14.000000   2018.000000      0.0
# 75%    6.246417e+08      6.000000     22.000000   2018.000000      0.0
# max    9.538793e+10     12.000000     31.000000   2018.000000      0.0
#
#              SubDir       SubDir2
# count  10113.000000  10113.000000
# mean       1.427272      6.074360
# std        0.551426      5.634908
# min        0.000000      1.000000
# 25%        1.000000      1.000000
# 50%        1.000000      4.000000
# 75%        2.000000     11.000000
# max        2.000000     17.000000

# %%
from __future__ import absolute_import, division, print_function

import tensorflow as tf
from tensorflow import keras

import numpy as np

print(tf.__version__)
# Out:
# /home/linux/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.10.0

# %%
boston_housing = keras.datasets.boston_housing

(train_data, train_labels), (test_data, test_labels) = boston_housing.load_data()

# Shuffle the training set
order = np.argsort(np.random.random(train_labels.shape))
train_data = train_data[order]
train_labels = train_labels[order]

print("Training set: {}".format(train_data.shape))  # 404 examples, 13 features
print("Testing set:  {}".format(test_data.shape))
# Out:
# Training set: (404, 13)
# Testing set:  (102, 13)

# %%
test_data.shape
# Out:
# (102, 13)

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
                'TAX', 'PTRATIO', 'B', 'LSTAT']

df = pd.DataFrame(train_data, columns=column_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 0  0.07875  45.0   3.44   0.0  0.437  6.782  41.1  3.7886   5.0  398.0
# 1  4.55587   0.0  18.10   0.0  0.718  3.561  87.9  1.6132  24.0  666.0
# 2  0.09604  40.0   6.41   0.0  0.447  6.854  42.8  4.2673   4.0  254.0
# 3  0.01870  85.0   4.15   0.0  0.429  6.516  27.7  8.5353   4.0  351.0
# 4  0.52693   0.0   6.20   0.0  0.504  8.725  83.0  2.8944   8.0  307.0
#
#    PTRATIO       B  LSTAT
# 0     15.2  393.87   6.68
# 1     20.2  354.70   7.12
# 2     17.6  396.90   2.98
# 3     17.9  392.43   6.36
# 4     17.4  382.00   4.63

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.745111   11.480198   11.104431    0.061881    0.557356    6.267082
# std      9.240734   23.767711    6.811308    0.241238    0.117293    0.709788
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081437    0.000000    5.130000    0.000000    0.453000    5.874750
# 50%      0.268880    0.000000    9.690000    0.000000    0.538000    6.198500
# 75%      3.674808   12.500000   18.100000    0.000000    0.631000    6.609000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.725000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.010644    3.740271    9.440594  405.898515   18.475990  354.783168
# std     27.940665    2.030215    8.698360  166.374543    2.200382   94.111148
# min      2.900000    1.129600    1.000000  188.000000   12.600000    0.320000
# 25%     45.475000    2.077100    4.000000  279.000000   17.225000  374.672500
# 50%     78.500000    3.142300    5.000000  330.000000   19.100000  391.250000
# 75%     94.100000    5.118000   24.000000  666.000000   20.200000  396.157500
# max    100.000000   10.710300   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  404.000000
# mean    12.740817
# std      7.254545
# min      1.730000
# 25%      6.890000
# 50%     11.395000
# 75%     17.092500
# max     37.970000
